# %% [markdown]
# # Bank cleanining class

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from app import DataProcess

# %%
bank = DataProcess()

# %%
df = bank.load(file_name= 'bs140513_032310')
# Out:
# step             180
# customer        4112
# age                8
# gender             4
# zipcodeOri         1
# merchant          50
# zipMerchant        1
# category          15
# amount         23767
# fraud              2
# dtype: int64
#    step       customer  age gender zipcodeOri       merchant zipMerchant  \
# 0     0  'C1093826151'  '4'    'M'    '28007'   'M348934600'     '28007'
# 1     0   'C352968107'  '2'    'M'    '28007'   'M348934600'     '28007'
# 2     0  'C2054744914'  '4'    'F'    '28007'  'M1823072687'     '28007'
# 3     0  'C1760612790'  '3'    'M'    '28007'   'M348934600'     '28007'
# 4     0   'C757503768'  '5'    'M'    '28007'   'M348934600'     '28007'
#
#               category  amount  fraud
# 0  'es_transportation'    4.55      0
# 1  'es_transportation'   39.68      0
# 2  'es_transportation'   26.89      0
# 3  'es_transportation'   17.25      0
# 4  'es_transportation'   35.72      0

# %%
df
bank.raw_df.nunique()
# Out:
# step             180
# customer        4112
# age                8
# gender             4
# zipcodeOri         1
# merchant          50
# zipMerchant        1
# category          15
# amount         23767
# fraud              2
# dtype: int64

# %%
df_unique = bank.raw_df.loc[:,bank.raw_df.apply(pd.Series.nunique) != 1]
df_unique.head()
# Out:
#    step       customer  age gender       merchant             category  \
# 0     0  'C1093826151'  '4'    'M'   'M348934600'  'es_transportation'
# 1     0   'C352968107'  '2'    'M'   'M348934600'  'es_transportation'
# 2     0  'C2054744914'  '4'    'F'  'M1823072687'  'es_transportation'
# 3     0  'C1760612790'  '3'    'M'   'M348934600'  'es_transportation'
# 4     0   'C757503768'  '5'    'M'   'M348934600'  'es_transportation'
#
#    amount  fraud
# 0    4.55      0
# 1   39.68      0
# 2   26.89      0
# 3   17.25      0
# 4   35.72      0

# %%
df_unique.nunique()
# Out:
# step          180
# customer     4112
# age             8
# gender          4
# merchant       50
# category       15
# amount      23767
# fraud           2
# dtype: int64

# %%
bank.cleanc()
# Out:
#    step       customer  age gender       merchant             category  \
# 0     0  'C1093826151'  '4'    'M'   'M348934600'  'es_transportation'
# 1     0   'C352968107'  '2'    'M'   'M348934600'  'es_transportation'
# 2     0  'C2054744914'  '4'    'F'  'M1823072687'  'es_transportation'
# 3     0  'C1760612790'  '3'    'M'   'M348934600'  'es_transportation'
# 4     0   'C757503768'  '5'    'M'   'M348934600'  'es_transportation'
#
#    amount  fraud
# 0    4.55      0
# 1   39.68      0
# 2   26.89      0
# 3   17.25      0
# 4   35.72      0
#         step       customer  age gender       merchant  \
# 0          0  'C1093826151'  '4'    'M'   'M348934600'
# 1          0   'C352968107'  '2'    'M'   'M348934600'
# 2          0  'C2054744914'  '4'    'F'  'M1823072687'
# 3          0  'C1760612790'  '3'    'M'   'M348934600'
# 4          0   'C757503768'  '5'    'M'   'M348934600'
# 5          0  'C1315400589'  '3'    'F'   'M348934600'
# ...
